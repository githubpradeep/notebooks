# %% [markdown]
# <a href="https://colab.research.google.com/github/githubpradeep/notebooks/blob/main/Fuyu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/huggingface/transformers.git

# %%
# !wget https://huggingface.co/adept-hf-collab/fuyu-8b/resolve/main/bus.png
# Out:
# --2023-10-19 15:56:25--  https://huggingface.co/adept-hf-collab/fuyu-8b/resolve/main/bus.png
# Resolving huggingface.co (huggingface.co)... 18.172.134.124, 18.172.134.4, 18.172.134.88, ...
# Connecting to huggingface.co (huggingface.co)|18.172.134.124|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: /adept/fuyu-8b/resolve/main/bus.png [following]
# --2023-10-19 15:56:25--  https://huggingface.co/adept/fuyu-8b/resolve/main/bus.png
# Reusing existing connection to huggingface.co:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 563807 (551K) [image/png]
# Saving to: ‘bus.png’
#
# bus.png             100%[===================>] 550.59K  --.-KB/s    in 0.06s
#
# 2023-10-19 15:56:25 (8.79 MB/s) - ‘bus.png’ saved [563807/563807]

# %%
# !pip install accelerate bitsandbytes

# %%
from transformers import FuyuForCausalLM, AutoTokenizer, FuyuProcessor, FuyuImageProcessor
from PIL import Image

# load model, tokenizer, and processor
pretrained_path = "adept/fuyu-8b"
tokenizer = AutoTokenizer.from_pretrained(pretrained_path)

image_processor = FuyuImageProcessor()
processor = FuyuProcessor(image_processor=image_processor, tokenizer=tokenizer)

model = FuyuForCausalLM.from_pretrained(pretrained_path, device_map="cuda:0", load_in_4bit=True)
# Out:
# ...
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ...

# %%
# test inference
text_prompt = "Generate a coco-style caption.\n"
image_path = "bus.png"  # https://huggingface.co/adept-hf-collab/fuyu-8b/blob/main/bus.png
image_pil = Image.open(image_path)
model_inputs = processor(text=text_prompt, images=[image_pil], device="cuda:0")
for k, v in model_inputs.items():
    model_inputs[k] = v.to("cuda:0")

generation_output = model.generate(**model_inputs, max_new_tokens=6)
generation_text = processor.batch_decode(generation_output[:, -6:], skip_special_tokens=True)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:71013 for open-end generation.
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/nn/modules.py:224: UserWarning: Input type into Linear4bit is torch.float16, but bnb_4bit_compute_type=torch.float32 (default). This will lead to slow inference or training speed.
#   warnings.warn(f'Input type into Linear4bit is torch.float16, but bnb_4bit_compute_type=torch.float32 (default). This will lead to slow inference or training speed.')

# %%
generation_text
# Out:
# ['A blue bus parked on the side of a road']

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !wget https://huggingface.co/adept-hf-collab/fuyu-8b/resolve/main/chart.png
# Out:
# --2023-10-19 16:01:00--  https://huggingface.co/adept-hf-collab/fuyu-8b/resolve/main/chart.png
# Resolving huggingface.co (huggingface.co)... 18.172.134.24, 18.172.134.88, 18.172.134.4, ...
# Connecting to huggingface.co (huggingface.co)|18.172.134.24|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: /adept/fuyu-8b/resolve/main/chart.png [following]
# --2023-10-19 16:01:01--  https://huggingface.co/adept/fuyu-8b/resolve/main/chart.png
# Reusing existing connection to huggingface.co:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 124150 (121K) [image/png]
# Saving to: ‘chart.png’
#
# chart.png           100%[===================>] 121.24K  --.-KB/s    in 0.02s
#
# 2023-10-19 16:01:01 (4.82 MB/s) - ‘chart.png’ saved [124150/124150]

# %%
text_prompt = "What is the highest life expectancy at birth of male?\n"
image_path = "chart.png"  # https://huggingface.co/adept-hf-collab/fuyu-8b/blob/main/chart.png
image_pil = Image.open(image_path)

# %%
model_inputs = processor(text=text_prompt, images=[image_pil], device="cuda:0")

# %%
for k, v in model_inputs.items():
    model_inputs[k] = v.to("cuda:0")

generation_output = model.generate(**model_inputs, max_new_tokens=16)
generation_text = processor.batch_decode(generation_output[:, -16:], skip_special_tokens=True)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:71013 for open-end generation.

# %%
generation_text
# Out:
# ['The life expectancy at birth of males in the graph is 80.7 years.\n']

# %%
# !wget https://imgcdn.floweraura.com/butterscotch-cake-with-birthday-topper-9814390ca-A_0.jpg
# Out:
# --2023-10-19 16:01:09--  https://imgcdn.floweraura.com/butterscotch-cake-with-birthday-topper-9814390ca-A_0.jpg
# Resolving imgcdn.floweraura.com (imgcdn.floweraura.com)... 18.160.249.93, 18.160.249.80, 18.160.249.87, ...
# Connecting to imgcdn.floweraura.com (imgcdn.floweraura.com)|18.160.249.93|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 114923 (112K) [image/jpeg]
# Saving to: ‘butterscotch-cake-with-birthday-topper-9814390ca-A_0.jpg’
#
# butterscotch-cake-w 100%[===================>] 112.23K  --.-KB/s    in 0.03s
#
# 2023-10-19 16:01:09 (4.24 MB/s) - ‘butterscotch-cake-with-birthday-topper-9814390ca-A_0.jpg’ saved [114923/114923]

# %%
text_prompt = "Describe the image?\n"
image_path = "butterscotch-cake-with-birthday-topper-9814390ca-A_0.jpg"  # https://huggingface.co/adept-hf-collab/fuyu-8b/blob/main/chart.png
image_pil = Image.open(image_path)
model_inputs = processor(text=text_prompt, images=[image_pil], device="cuda:0")
for k, v in model_inputs.items():
    model_inputs[k] = v.to("cuda:0")

generation_output = model.generate(**model_inputs, max_new_tokens=20)
generation_text = processor.batch_decode(generation_output[:, -20:], skip_special_tokens=True)
generation_text
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:71013 for open-end generation.
# ['The image features a birthday cake placed on a table, with a white tablecloth underneath it. The cake is decorated with a']

# %%
text_prompt = "What are the ingredients of the cake?\n"
image_path = "butterscotch-cake-with-birthday-topper-9814390ca-A_0.jpg"  # https://huggingface.co/adept-hf-collab/fuyu-8b/blob/main/chart.png
image_pil = Image.open(image_path)
model_inputs = processor(text=text_prompt, images=[image_pil], device="cuda:0")
for k, v in model_inputs.items():
    model_inputs[k] = v.to("cuda:0")

generation_output = model.generate(**model_inputs, max_new_tokens=20)
generation_text = processor.batch_decode(generation_output[:, -20:], skip_special_tokens=True)
generation_text
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:71013 for open-end generation.
# ['The cake is decorated with a white frosting base, red stars, and orange icing.\n']

# %%
# !wget https://i.insider.com/560ebbe7dd0895325c8b458e?width=700
# Out:
# --2023-10-19 16:01:23--  https://i.insider.com/560ebbe7dd0895325c8b458e?width=700
# Resolving i.insider.com (i.insider.com)... 151.101.2.217, 151.101.66.217, 151.101.130.217, ...
# Connecting to i.insider.com (i.insider.com)|151.101.2.217|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 201306 (197K) [image/png]
# Saving to: ‘560ebbe7dd0895325c8b458e?width=700’
#
# 560ebbe7dd0895325c8 100%[===================>] 196.59K  --.-KB/s    in 0.04s
#
# 2023-10-19 16:01:23 (5.00 MB/s) - ‘560ebbe7dd0895325c8b458e?width=700’ saved [201306/201306]

# %%
text_prompt = "What is the game?\n"
image_path = "560ebbe7dd0895325c8b458e?width=700"  # https://huggingface.co/adept-hf-collab/fuyu-8b/blob/main/chart.png
image_pil = Image.open(image_path)
model_inputs = processor(text=text_prompt, images=[image_pil], device="cuda:0")
for k, v in model_inputs.items():
    model_inputs[k] = v.to("cuda:0")

generation_output = model.generate(**model_inputs, max_new_tokens=20)
generation_text = processor.batch_decode(generation_output[:, -20:], skip_special_tokens=True)
generation_text
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:71013 for open-end generation.
# ['\n\x04 The game is a classic Mario game, featuring different levels, characters, and gameplay mechanics.\n']

# %%
text_prompt = "What is the next immediate action player should take?\n"
image_path = "560ebbe7dd0895325c8b458e?width=700"  # https://huggingface.co/adept-hf-collab/fuyu-8b/blob/main/chart.png
image_pil = Image.open(image_path)
model_inputs = processor(text=text_prompt, images=[image_pil], device="cuda:0")
for k, v in model_inputs.items():
    model_inputs[k] = v.to("cuda:0")

generation_output = model.generate(**model_inputs, max_new_tokens=5)
generation_text = processor.batch_decode(generation_output[:, -5:], skip_special_tokens=True)
generation_text
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:71013 for open-end generation.
# ['After Mario is finished jumping']

# %%
# !wget https://parade.com/.image/t_share/MTk3NTUzMDg1MDA1MTEzMDI2/super-mario-bros-movie.webp
# Out:
# --2023-10-19 16:01:31--  https://parade.com/.image/t_share/MTk3NTUzMDg1MDA1MTEzMDI2/super-mario-bros-movie.webp
# Resolving parade.com (parade.com)... 151.101.2.98, 151.101.130.98, 151.101.194.98, ...
# Connecting to parade.com (parade.com)|151.101.2.98|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 80316 (78K) [image/webp]
# Saving to: ‘super-mario-bros-movie.webp’
#
# super-mario-bros-mo 100%[===================>]  78.43K  --.-KB/s    in 0.02s
#
# 2023-10-19 16:01:32 (3.55 MB/s) - ‘super-mario-bros-movie.webp’ saved [80316/80316]

# %%
text_prompt = "Whats happening in the image?\n"
image_path = "super-mario-bros-movie.webp"  # https://huggingface.co/adept-hf-collab/fuyu-8b/blob/main/chart.png
image_pil = Image.open(image_path)
model_inputs = processor(text=text_prompt, images=[image_pil], device="cuda:0")
for k, v in model_inputs.items():
    model_inputs[k] = v.to("cuda:0")

generation_output = model.generate(**model_inputs, max_new_tokens=25)
generation_text = processor.batch_decode(generation_output[:, -25:], skip_special_tokens=True)
generation_text
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:71013 for open-end generation.
# ['In the image, a princess and a mario character are standing next to each other in a park-like setting. The princess is wearing a pink']
