# %%
import os
os.environ['OPENAI_API_KEY'] = ''
api_key=''
import os
os.environ['GROQ_API_KEY'] = api_key

# %%
# Optional: add tracing to visualize the agent trajectories
import os
from getpass import getpass

from langchain_core.prompts import ChatPromptTemplate
from langchain_groq import ChatGroq

# %%
import operator
from typing import Annotated, Any, List, Dict
from typing_extensions import TypedDict
from langgraph.graph import StateGraph, END
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.utilities.tavily_search import TavilySearchAPIWrapper
import json 
class State(TypedDict):
    input: str
    responses: str
    feedback: str
    aggregated_response: Annotated[list, operator.add]
    final_answer: str
    iteration: int
    max_iterations: int
    reflection: str

# Initialize models and search tool
proposer_models = [
    ChatGroq(temperature=0, model_name="llama3-70b-8192",),
    ChatGroq(temperature=0, model_name="llama3-8b-8192",),
    ChatGroq(temperature=0, model_name="mixtral-8x7b-32768"),
]

aggregator_model = ChatOpenAI(model="gpt-4o", temperature=0)
reflector_model = ChatOpenAI(model="gpt-4o", temperature=0)
# Out:
# /Users/pradeep.borado/.conda/envs/cv/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 0.3.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   warn_deprecated(

# %%
class Proposer:
    def __init__(self, model: ChatOpenAI, id: str):
        self.model = model
        self.id = id

    def __call__(self, state: State) -> Dict[str, Dict[str, str]]:
        
        prompt = ChatPromptTemplate.from_messages([
            ("human", "Please provide a response to the following prompt: {input}\n\n"
             "The previous response was {response}\n\n"
             "The provided feedbackw was {feedback} \n\n"
                      "Always answer with as much detail as possible.")
        ])
        response = self.model(prompt.format_messages(
            input=state["input"],
            response=state['responses'],
            feedback=state['feedback']
            
        ))
        
        
        
        return {"aggregated_response": [json.dumps({self.id: response.content})]}

# %%
def aggregator(state: State) -> State:
    prompt = ChatPromptTemplate.from_messages([
        #("human", "Given the following responses to the prompt '{input}', please synthesize them into a single, high-quality response:\n\n{responses}")
        ("human", '''
        You have been provided with a set of responses from various open-source models to the  user query '{input}'.
        Your task is to synthesize these responses into a single, high-quality response.
        It is crucial to critically evaluate the information provided in these responses, 
        recognizing that some of it may be biased or incorrect. 
        Your response should not simply replicate the given answers but should offer a refined, accurate, and comprehensive reply to the instruction. Ensure your response is well-structured, coherent, and adheres to the highest standards of accuracy and reliability.
 
        Responses from models:
        \n\n{responses}

''')
    ])
    response = aggregator_model(prompt.format_messages(
        input=state["input"],
        responses="\n\n".join(state["aggregated_response"])
    ))
    state["responses"] = response.content
    return state

# %%
from langchain.prompts import ChatPromptTemplate
from pydantic import BaseModel, Field
from langchain_openai import ChatOpenAI
from langchain.output_parsers import PydanticOutputParser


class GradeGeneration(BaseModel):
    """Binary score for relevance check on retrieved documents."""
    score: str = Field(
        description="Is this the correct answer to the question, 'yes' or 'no'"
    )
    feedback: str = Field(
        description="Provided specific feedback for improvement"
    )
        
def reflector(state: State) -> State:
    parser = PydanticOutputParser(pydantic_object=GradeGeneration)

    prompt  = ChatPromptTemplate.from_messages([
            ("human", "Given the following answer to the question: '{input}'\n\n"
            "Answer: {aggregated_response}\n\n"
                      "If the answer is satisfactory and complete, grade it as yes. \n"
    "Provide json object with  feedback string and binary score 'yes' or 'no' score to indicate whether the answer is correct"
            )
        ])
    chain = prompt | reflector_model | parser

    response = chain.invoke({
        'input':state["input"],
        'aggregated_response':state["responses"]
    })
    state["reflection"] = response.score
    state['feedback'] = response.feedback
    state["iteration"] += 1
    return state

# %%
def should_continue(state: State) -> str:
    if state["iteration"] >= state["max_iterations"]:# or "YES" in state["reflection"].upper():
        state["final_answer"] = state["responses"]
        return "end"
    return "refine"

# Create the graph
workflow = StateGraph(State)

# Add nodes
for i, model in enumerate(proposer_models):
    workflow.add_node(f"proposer_{i}", Proposer(model, f"proposer_{i}"))
workflow.add_node("aggregator", aggregator)
workflow.add_node("reflector", reflector)

# Define edges
workflow.set_entry_point("proposer_0")
for i in range(1, len(proposer_models)):
    workflow.add_edge(f"proposer_0", f"proposer_{i}")
    workflow.add_edge(f"proposer_{i}", "aggregator")
workflow.add_edge("aggregator", "reflector")
workflow.add_conditional_edges(
    "reflector",
    should_continue,
    {
        "refine": "proposer_0",
        "end": END
    }
)

# %%
app = workflow.compile()

# %%
def query_moa(question):
    # Run the graph
    initial_state = {
        "input": question,
        "responses": '',
        'feedback':"",
        "aggregated_response": [],
        "final_answer": "",
        "iteration": 0,
        "max_iterations": 3,
        "reflection": ""
    }
    for output in app.stream(initial_state):
        for key, value in output.items():
            print(f"Finished running: {key}:")
    print(value['responses'])
    return value

# %%
value = query_moa("Explain the latest advancements in quantum computing and their potential applications.")
# Out:
# Finished running: proposer_0:
# Finished running: proposer_1:
# Finished running: proposer_2:
# Finished running: aggregator:
# Finished running: reflector:
# Finished running: proposer_0:
# Finished running: proposer_2:
# Finished running: proposer_1:
# Finished running: aggregator:
# Finished running: reflector:
# Finished running: proposer_0:
# Finished running: proposer_2:
# Finished running: proposer_1:
# Finished running: aggregator:
# Finished running: reflector:
# ### Latest Advancements in Quantum Computing and Their Potential Applications
#
# Quantum computing has made remarkable strides in recent years, with significant advancements in hardware, software, and algorithm development. These innovations are pushing the boundaries of what is possible with this revolutionary technology, promising to transform various industries and fields.
#
# #### Latest Advancements in Quantum Computing
#
# 1. **Quantum Processors with Higher Qubit Counts**:
#    - Companies like Google, IBM, and Rigetti Computing have developed quantum processors with increasingly higher qubit counts. For instance, Google's Sycamore processor features 53 qubits and achieved quantum supremacy in 2019 by performing a calculation that would be infeasible for classical computers. IBM and Rigetti have also made significant progress, with processors featuring 53, 72, and even 128 qubits. These advancements enable more complex calculations and simulations, such as simulating the behavior of molecules and materials, optimizing complex systems, and solving intricate optimization problems.
#
# 2. **Improved Quantum Error Correction**:
#    - Quantum systems are highly sensitive to environmental disturbances, which can lead to errors in calculations. Researchers have made significant progress in developing robust error correction techniques, such as surface codes and the Gottesman-Kitaev-Preskill (GKP) code. These methods are crucial for building large-scale, reliable quantum computers. For example, the GKP code uses a combination of quantum error correction and classical error correction to achieve high fidelity in quantum computations.
#
# 3. **Advances in Quantum Algorithms**:
#    - New quantum algorithms have been developed to tackle specific problems. Notable examples include Shor's algorithm for factorization, Grover's algorithm for search, and the Variational Quantum Eigensolver (VQE) for simulating complex systems. Additionally, algorithms like the Quantum Approximate Optimization Algorithm (QAOA) and Quantum Circuit Learning (QCL) are being explored for optimization and machine learning tasks. These algorithms have the potential to revolutionize fields such as materials science, chemistry, and biology.
#
# 4. **Quantum-Classical Hybrid Approaches**:
#    - Researchers are exploring hybrid systems that combine classical and quantum computing to leverage the strengths of both paradigms. These approaches, such as QAOA, can solve complex problems more efficiently than classical or quantum systems alone. For example, QAOA has been used to optimize complex systems, such as the Ising model, by combining classical optimization techniques with quantum computing.
#
# 5. **Quantum Software Development**:
#    - Quantum software frameworks like Qiskit, Cirq, and Q# (Quantum Sharp) have been developed to simplify the creation of quantum algorithms and applications. These tools are essential for making quantum computing more accessible to researchers and developers. For instance, Qiskit provides a comprehensive set of tools for quantum computing, including a quantum compiler, simulator, and quantum circuit library.
#
# #### Potential Applications of Quantum Computing
#
# The advancements in quantum computing have far-reaching implications for various industries and fields:
#
# 1. **Cryptography and Cybersecurity**:
#    - Quantum computers have the potential to break classical encryption algorithms, posing a threat to current cybersecurity measures. However, they can also be used to develop unbreakable quantum encryption methods, such as Quantum Key Distribution (QKD), ensuring secure communication. QKD uses quantum mechanics to encode and decode messages, making it virtually unbreakable.
#
# 2. **Optimization and Machine Learning**:
#    - Quantum computers can efficiently solve complex optimization problems, leading to breakthroughs in logistics, finance, and machine learning. For example, they can optimize trading strategies, manage risk more effectively, and accelerate machine learning algorithms for tasks like image recognition and natural language processing. Quantum computers can also be used to optimize complex systems, such as supply chains and logistics networks.
#
# 3. **Materials Science and Chemistry**:
#    - Quantum simulation can help design new materials with unique properties, leading to advancements in energy storage, catalysis, and pharmaceuticals. Quantum computers can simulate the behavior of molecules at the atomic level, enabling the discovery of new materials and drugs. For instance, quantum computers can simulate the behavior of molecules in complex systems, such as biological systems, to understand their behavior and develop new treatments.
#
# 4. **Weather Forecasting and Climate Modeling**:
#    - Quantum computers can simulate complex weather patterns and climate models, enabling more accurate predictions and better decision-making for climate change mitigation and adaptation. For instance, quantum computers can simulate the behavior of complex weather systems, such as hurricanes and tornadoes, to improve weather forecasting and climate modeling.
#
# 5. **Healthcare and Biomedical Research**:
#    - Quantum computing can accelerate the discovery of new drugs, optimize personalized medicine, and improve our understanding of complex biological systems. Analyzing large amounts of genetic data to develop personalized treatments for diseases is one promising application. For instance, quantum computers can simulate the behavior of complex biological systems, such as protein folding, to understand their behavior and develop new treatments.
#
# 6. **Financial Modeling and Portfolio Optimization**:
#    - Quantum computers can quickly analyze vast amounts of financial data, enabling more accurate predictions and optimized investment strategies. This can lead to more efficient and profitable financial decisions. For instance, quantum computers can simulate the behavior of complex financial systems, such as stock markets and bond markets, to optimize investment strategies.
#
# 7. **Supply Chain Optimization and Logistics**:
#    - Quantum computers can solve complex optimization problems in supply chains, leading to more efficient operations and reduced costs. For instance, quantum computers can optimize complex supply chain networks, such as logistics and transportation networks, to reduce costs and improve efficiency.
#
# ### Conclusion
#
# The latest advancements in quantum computing are bringing us closer to realizing the full potential of this transformative technology. As research continues to push the boundaries, we can expect significant impacts across various industries and fields, leading to breakthroughs and innovations that will shape the future. While there are still many technical challenges to overcome, the progress being made is promising, and practical applications of quantum computing are likely to become increasingly prevalent in the coming years.

# %%
value=query_moa("Write the snake game in python without any errors")
# Out:
# Finished running: proposer_0:
# Finished running: proposer_1:
# Finished running: proposer_2:
# Finished running: aggregator:
# Finished running: reflector:
# Finished running: proposer_0:
# Finished running: proposer_1:
# Finished running: proposer_2:
# Finished running: aggregator:
# Finished running: reflector:
# Finished running: proposer_0:
# Finished running: proposer_1:
# Finished running: proposer_2:
# Finished running: aggregator:
# Finished running: reflector:
# Here is a comprehensive and refined implementation of the classic Snake game in Python using the Pygame library. This version includes detailed explanations and improvements to ensure clarity and functionality.
#
# ```python
# import pygame
# import random
# import sys
#
# # Initialize Pygame
# pygame.init()
#
# # Set up some constants
# WIDTH, HEIGHT = 800, 600
# BLOCK_SIZE = 20
# SPEED = 15
#
# # Set up some colors
# BLACK = (0, 0, 0)
# WHITE = (255, 255, 255)
# RED = (255, 0, 0)
# GREEN = (0, 255, 0)
# BLUE = (50, 153, 213)
# YELLOW = (255, 255, 102)
#
# # Set up the display
# screen = pygame.display.set_mode((WIDTH, HEIGHT))
# pygame.display.set_caption("Snake Game")
#
# # Set up the font
# font_style = pygame.font.SysFont("bahnschrift", 25)
# score_font = pygame.font.SysFont("comicsansms", 35)
#
# def display_score(score):
#     """
#     Displays the current score on the screen.
#     """
#     value = score_font.render("Your Score: " + str(score), True, YELLOW)
#     screen.blit(value, [0, 0])
#
# def draw_snake(snake_list):
#     """
#     Draws the snake on the screen.
#     """
#     for x in snake_list:
#         pygame.draw.rect(screen, BLACK, [x[0], x[1], BLOCK_SIZE, BLOCK_SIZE])
#
# def display_message(msg, color):
#     """
#     Displays a message on the screen.
#     """
#     mesg = font_style.render(msg, True, color)
#     screen.blit(mesg, [WIDTH / 6, HEIGHT / 3])
#
# def game_loop():
#     """
#     The main game loop.
#     """
#     game_over = False
#     game_close = False
#
#     x1 = WIDTH / 2
#     y1 = HEIGHT / 2
#
#     x1_change = 0
#     y1_change = 0
#
#     snake_list = []
#     length_of_snake = 1
#
#     foodx = round(random.randrange(0, WIDTH - BLOCK_SIZE) / 20.0) * 20.0
#     foody = round(random.randrange(0, HEIGHT - BLOCK_SIZE) / 20.0) * 20.0
#
#     clock = pygame.time.Clock()
#
#     while not game_over:
#
#         while game_close:
#             screen.fill(BLUE)
#             display_message("You Lost! Press C-Play Again or Q-Quit", RED)
#             display_score(length_of_snake - 1)
#             pygame.display.update()
#
#             for event in pygame.event.get():
#                 if event.type == pygame.KEYDOWN:
#                     if event.key == pygame.K_q:
#                         game_over = True
#                         game_close = False
#                     if event.key == pygame.K_c:
#                         game_loop()
#
#         for event in pygame.event.get():
#             if event.type == pygame.QUIT:
#                 game_over = True
#             if event.type == pygame.KEYDOWN:
#                 if event.key == pygame.K_LEFT and x1_change == 0:
#                     x1_change = -BLOCK_SIZE
#                     y1_change = 0
#                 elif event.key == pygame.K_RIGHT and x1_change == 0:
#                     x1_change = BLOCK_SIZE
#                     y1_change = 0
#                 elif event.key == pygame.K_UP and y1_change == 0:
#                     y1_change = -BLOCK_SIZE
#                     x1_change = 0
#                 elif event.key == pygame.K_DOWN and y1_change == 0:
#                     y1_change = BLOCK_SIZE
#                     x1_change = 0
#
#         if x1 >= WIDTH or x1 < 0 or y1 >= HEIGHT or y1 < 0:
#             game_close = True
#         x1 += x1_change
#         y1 += y1_change
#         screen.fill(BLUE)
#         pygame.draw.rect(screen, GREEN, [foodx, foody, BLOCK_SIZE, BLOCK_SIZE])
#         snake_head = [x1, y1]
#         snake_list.append(snake_head)
#         if len(snake_list) > length_of_snake:
#             del snake_list[0]
#
#         for x in snake_list[:-1]:
#             if x == snake_head:
#                 game_close = True
#
#         draw_snake(snake_list)
#         display_score(length_of_snake - 1)
#
#         pygame.display.update()
#
#         if x1 == foodx and y1 == foody:
#             foodx = round(random.randrange(0, WIDTH - BLOCK_SIZE) / 20.0) * 20.0
#             foody = round(random.randrange(0, HEIGHT - BLOCK_SIZE) / 20.0) * 20.0
#             length_of_snake += 1
#
#         clock.tick(SPEED)
#
#     pygame.quit()
#     sys.exit()
#
# game_loop()
# ```
#
# ### Explanation:
#
# 1. **Initialization**: The Pygame library is initialized, and constants for the game window size, block size, and speed are defined.
# 2. **Colors**: Various colors are defined for use in the game.
# 3. **Display Setup**: The game window is set up, and fonts for displaying text are initialized.
# 4. **Helper Functions**:
#     - `display_score(score)`: Displays the current score on the screen.
#     - `draw_snake(snake_list)`: Draws the snake on the screen.
#     - `display_message(msg, color)`: Displays a message on the screen.
# 5. **Game Loop**:
#     - Handles game over and game close states.
#     - Processes user input for controlling the snake.
#     - Updates the snake's position and checks for collisions with the walls, itself, and food.
#     - Draws the snake and food on the screen and updates the score.
#     - Controls the game speed using `pygame.time.Clock()`.
#
# ### Improvements and Additional Features:
#
# 1. **Score Display**: The score is displayed on the top-left corner of the screen and updates in real-time as the snake eats food.
# 2. **Game Over Message**: When the game is over, a message is displayed on the screen with options to play again or quit.
# 3. **Sound Effects**: You can add sound effects for eating food, colliding with walls, and game over using Pygame's `mixer` module.
# 4. **High Score Tracking**: Store the high score in a file and display it on the screen when the game starts.
# 5. **Different Levels**: Create different levels with varying speeds, wall layouts, and food spawn rates.
# 6. **Improved Graphics**: Use images for the snake, food, and walls to make the game more visually appealing.
#
# This implementation provides a complete and error-free Snake game in Python using Pygame. You can further enhance it by adding features like sound effects, high score tracking, and different levels.

# %%
value = query_moa("if we lay 5 shirts in the sun and it takes 4 hours to dry, how long would 20 shirts take to dry?")
# Out:
# Finished running: proposer_0:
# Finished running: proposer_1:
# Finished running: proposer_2:
# Finished running: aggregator:
# Finished running: reflector:
# Finished running: proposer_0:
# Finished running: proposer_2:
# Finished running: proposer_1:
# Finished running: aggregator:
# Finished running: reflector:
# Finished running: proposer_0:
# Finished running: proposer_2:
# Finished running: proposer_1:
# Finished running: aggregator:
# Finished running: reflector:
# To determine how long it would take for 20 shirts to dry in the sun, we need to consider the relationship between the number of shirts and the drying time. Initially, it might seem logical to assume that the drying time is directly proportional to the number of shirts. However, this assumption oversimplifies the complex factors that influence the drying process.
#
# ### Key Factors Affecting Drying Time:
#
# 1. **Exposure to Sunlight**: The amount of direct sunlight each shirt receives is crucial. If the shirts are laid out in a way that maximizes exposure, the drying time will be more efficient.
# 2. **Air Circulation**: Good air circulation around the shirts enhances evaporation and speeds up the drying process.
# 3. **Environmental Conditions**: Temperature, humidity, and wind strength significantly impact the rate of evaporation and drying.
# 4. **Material and Thickness**: The type of fabric and its thickness affect how quickly the shirts absorb and release moisture.
#
# ### Proportionality Assumption:
#
# If we were to assume that drying time is directly proportional to the number of shirts, we would calculate:
# - 5 shirts take 4 hours to dry.
# - Therefore, 20 shirts would take \( \frac{20}{5} \times 4 = 16 \) hours to dry.
#
# However, this assumption is flawed because it neglects the critical role of environmental conditions and layout in the drying process.
#
# ### Realistic Scenario:
#
# In reality, the drying time is not directly proportional to the number of shirts. The primary factors are the environmental conditions and how the shirts are laid out. If the shirts are spread out evenly and receive the same amount of sunlight and air circulation, the drying time should remain approximately the same regardless of the number of shirts.
#
# ### Conclusion:
#
# Given that the drying conditions (sunlight, air circulation, temperature, and humidity) remain constant and the shirts are laid out in a similar manner, the drying time for 20 shirts would still be approximately 4 hours, just like it is for 5 shirts. The drying time is not significantly affected by the number of shirts but rather by how they are exposed to the drying conditions.
#
# Therefore, **20 shirts would take approximately 4 hours to dry in the sun, assuming consistent drying conditions and proper layout.** This conclusion is supported by the understanding that the drying process is primarily influenced by environmental factors and layout, rather than the number of shirts.

# %%
value = query_moa('''Maria is staying at a hotel that charges $99.95 per night plus tax for a room. A tax of 8% is applied to the room rate, 
and an additional onetime untaxed fee of $5.00 is charged by the hotel. 
Which of the following represents Maria’s total charge, in dollars, for staying x nights?  (99.95 + 0.08x) + 5  1.08(99.95x) + 5  1.08(99.95x + 5)  1.08(99.95 + 5)x''')
# Out:
# Finished running: proposer_0:
# Finished running: proposer_1:
# Finished running: proposer_2:
# Finished running: aggregator:
# Finished running: reflector:
# Finished running: proposer_0:
# Finished running: proposer_1:
# Finished running: proposer_2:
# Finished running: aggregator:
# Finished running: reflector:
# Finished running: proposer_0:
# Finished running: proposer_2:
# Finished running: proposer_1:
# Finished running: aggregator:
# Finished running: reflector:
# To determine Maria's total charge for staying \( x \) nights at a hotel, we need to consider the following components:
#
# 1. **Nightly Room Rate**: $99.95 per night.
# 2. **Tax**: 8% of the nightly room rate.
# 3. **One-time Fee**: $5.00, which is not subject to tax.
#
# ### Step-by-Step Calculation
#
# 1. **Calculate the Tax on the Nightly Room Rate**:
#    - The tax is 8% of $99.95.
#    - Tax per night = 0.08 × 99.95 = 7.996.
#
# 2. **Total Cost per Night Including Tax**:
#    - Total cost per night = Room rate + Tax
#    - Total cost per night = 99.95 + 7.996 = 107.946.
#
# 3. **Total Cost for \( x \) Nights**:
#    - Total cost for \( x \) nights = 107.946 × \( x \).
#
# 4. **Add the One-time Fee**:
#    - Total charge = 107.946\( x \) + 5.
#
# ### Verification Against Provided Options
#
# Now, let's compare this with the given options:
#
# 1. **Option A: (99.95 + 0.08x) + 5**:
#    - This is incorrect because it incorrectly adds the tax rate to the number of nights, which doesn't make sense.
#
# 2. **Option B: 1.08(99.95x) + 5**:
#    - This option is close to the correct representation, as it applies the tax rate to the room rate for \( x \) nights and then adds the one-time fee.
#
# 3. **Option C: 1.08(99.95x + 5)**:
#    - This is incorrect because it applies the tax rate to the sum of the room rate for \( x \) nights and the one-time fee, which is not correct.
#
# 4. **Option D: 1.08(99.95 + 5)x**:
#    - This is incorrect because it adds the one-time fee to the room rate before applying the tax rate and then multiplies by the number of nights, which is not the correct order of operations.
#
# ### Correct Representation
#
# The correct representation of Maria's total charge for staying \( x \) nights is:
#
# \[ 107.946x + 5 \]
#
# However, none of the provided options exactly match this correct representation. The closest correct option is:
#
# \[ 1.08(99.95x) + 5 \]
#
# This matches the correct calculation method, even though it uses a slightly simplified tax calculation. Therefore, the correct answer is Option B: \( 1.08(99.95x) + 5 \).

# %%
value =  query_moa('''There are three killers in a room.
Someone enters the room and kills one of them. Nobody leaves the room. How many killers are left in the room? Explain your reasoning step by step.''')
# Out:
# Finished running: proposer_0:
# Finished running: proposer_1:
# Finished running: proposer_2:
# Finished running: aggregator:
# Finished running: reflector:
# Finished running: proposer_0:
# Finished running: proposer_1:
# Finished running: proposer_2:
# Finished running: aggregator:
# Finished running: reflector:
# Finished running: proposer_0:
# Finished running: proposer_2:
# Finished running: proposer_1:
# Finished running: aggregator:
# Finished running: reflector:
# To determine how many killers are left in the room after the described events, let's break down the situation step by step:
#
# ### Initial Situation
# - There are three killers in the room. This means that each of these individuals has committed a murder or is capable of doing so.
#
# ### Event
# - Someone enters the room and kills one of the killers. This event is crucial in understanding the subsequent situation. The person who enters the room is not initially considered a killer, but their action changes their status.
#
# ### New Situation
# - Nobody leaves the room after the killing. This is an important detail, as it ensures that all individuals involved in the event remain in the room.
#
# ### Step-by-Step Reasoning
#
# 1. **Initial Count**: We start with three killers in the room, each with a history of violence or a propensity for murder.
# 2. **Entry and Action**: Someone enters the room and kills one of the original killers. This action implies that the person who entered the room has now committed a murder, making them a killer. This is a critical point, as it changes the status of the person who entered the room from a non-killer to a killer.
# 3. **Remaining Killers**: After the killing, one of the original killers is dead, leaving two of the original killers still alive. These two individuals still possess the characteristics of killers, having committed murders in the past or being capable of doing so.
# 4. **New Killer**: The person who entered the room and committed the murder is now also a killer and remains in the room. This individual has demonstrated their capacity for violence and is now part of the group of killers.
#
# ### Conclusion
# - **Original Killers**: Two of the original killers are still alive, maintaining their status as killers.
# - **New Killer**: The person who entered the room and killed one of the original killers is now a killer, adding to the total number of killers in the room.
#
# Therefore, there are a total of three killers left in the room: the two original killers who are still alive and the new killer who entered the room and committed the murder. This conclusion is logically sound, as it takes into account the initial number of killers, the event of the killing, and the new status of the person who entered the room.
#
# By breaking down the situation step by step, we can ensure that we account for the actions and status of all individuals involved, leading to the conclusion that there are still three killers in the room. The person who entered the room and committed the murder is now part of the group of killers, maintaining the total number of killers at three.

# %%
value =  query_moa('''A marble is put in a glass.
The glass is then turned upside down and put on a table.
Then the glass is picked up and put in a microwave. 
Where's the marble? Explain your reasoning step by step.''')
# Out:
# Finished running: proposer_0:
# Finished running: proposer_2:
# Finished running: proposer_1:
# Finished running: aggregator:
# Finished running: reflector:
# Finished running: proposer_0:
# Finished running: proposer_2:
# Finished running: proposer_1:
# Finished running: aggregator:
# Finished running: reflector:
# Finished running: proposer_0:
# Finished running: proposer_2:
# Finished running: proposer_1:
# Finished running: aggregator:
# Finished running: reflector:
# To determine the final location of the marble, let's break down the sequence of events step by step, considering the physical behavior of the marble and the glass:
#
# ### Step 1: A marble is put in a glass.
# At this point, the marble is inside the glass, resting at the bottom due to gravity. The glass is upright, and the marble is stable within the glass, surrounded by the glass walls and floor.
#
# ### Step 2: The glass is then turned upside down and put on a table.
# When the glass is turned upside down, gravity will cause the marble to move towards the new bottom, which is now the mouth of the glass. There are two possible outcomes:
#
# 1. **The marble rolls out of the glass:** If the glass is placed on the table with its mouth down and there is a slight gap or the table surface is not perfectly flat, the marble will roll out of the glass and come to rest on the table. This is because the marble is no longer constrained by the glass walls and is free to move under the influence of gravity.
#
# 2. **The marble remains inside the glass:** If the glass is placed firmly and flat on the table, the marble will come to rest against the mouth of the glass, still inside the glass. In this scenario, the marble is prevented from rolling out due to the glass's mouth being in contact with the table, creating a barrier.
#
# ### Step 3: Then the glass is picked up and put in a microwave.
# Now, let's consider the marble's location based on the two possible outcomes from Step 2:
#
# 1. **If the marble rolled out of the glass:** When the glass is picked up, the marble will remain on the table, unaffected by the glass's movement. The marble is no longer in contact with the glass and is not influenced by its movement.
#
# 2. **If the marble remained inside the glass:** When the glass is picked up and placed in the microwave, the marble will still be inside the glass, resting against the mouth. The marble's position relative to the glass remains unchanged, and it will be transported into the microwave along with the glass.
#
# ### Conclusion:
# The final location of the marble depends on whether it rolled out of the glass when the glass was turned upside down and placed on the table:
#
# - **If the marble rolled out of the glass, it is currently on the table.** The marble is stationary on the table, unaffected by the glass's movement or the microwave's operation.
# - **If the marble remained inside the glass, it is inside the glass, which is now in the microwave.** The marble is still resting against the glass's mouth, surrounded by the glass walls and floor.
#
# Given the typical behavior of a marble and a glass, it is more likely that the marble rolled out when the glass was turned upside down and placed on the table. Therefore, the most probable location of the marble is on the table. However, it is essential to acknowledge that there is a possibility, albeit smaller, that the marble remained inside the glass and is now in the microwave.

# %%
value = query_moa('Give me 10 sentences that end in the word Apple.')
# Out:
# Finished running: proposer_0:
# Finished running: proposer_1:
# Finished running: proposer_2:
# Finished running: aggregator:
# Finished running: reflector:
# Finished running: proposer_0:
# Finished running: proposer_1:
# Finished running: proposer_2:
# Finished running: aggregator:
# Finished running: reflector:
# Finished running: proposer_0:
# Finished running: proposer_1:
# Finished running: proposer_2:
# Finished running: aggregator:
# Finished running: reflector:
# Here are 10 well-crafted sentences that end with the word "Apple," synthesized from the provided responses:
#
# 1. The crunchy snack I love to eat is a juicy Apple.
# 2. The teacher asked the student to draw a picture of a shiny Apple.
# 3. The farmer carefully plucked the ripest fruit from the tree, a perfect Apple.
# 4. The tech giant's latest product is the iPhone, made by Apple.
# 5. The healthy breakfast option I chose was oatmeal with a slice of Apple.
# 6. The autumn festival featured a contest to see who could eat a pie filled with Apple.
# 7. The sweet aroma wafting from the bakery was that of a freshly baked Apple.
# 8. The still life painting featured a bowl of fruit, including a single, solitary Apple.
# 9. The recipe for the delicious dessert called for a mixture of sugar, cinnamon, and Apple.
# 10. The hike through the orchard ended with a refreshing snack of cold water and a crisp Apple.
#
# These sentences cover a variety of contexts such as food, art, technology, and daily activities, ensuring a comprehensive and engaging response.

# %%
value = query_moa('''It takes one person 5 hours to dig a 10 foot hole in the ground. 
How long would it take 50 people to dig a single 10 foot hole?'

''')
# Out:
# Finished running: proposer_0:
# Finished running: proposer_1:
# Finished running: proposer_2:
# Finished running: aggregator:
# Finished running: reflector:
# Finished running: proposer_0:
# Finished running: proposer_2:
# Finished running: proposer_1:
# Finished running: aggregator:
# Finished running: reflector:
# Finished running: proposer_0:
# Finished running: proposer_1:
# Finished running: proposer_2:
# Finished running: aggregator:
# Finished running: reflector:
# To determine how long it would take 50 people to dig a single 10-foot hole, we need to consider both theoretical calculations and practical limitations.
#
# ### Theoretical Calculation
#
# 1. **Individual Rate of Work**:
#    - One person can dig a 10-foot hole in 5 hours.
#    - Therefore, the rate of digging is \( \frac{10 \text{ feet}}{5 \text{ hours}} = 2 \text{ feet per hour} \).
#
# 2. **Combined Rate of 50 People**:
#    - If 50 people work together, their combined rate would be \( 50 \times 2 \text{ feet per hour} = 100 \text{ feet per hour} \).
#
# 3. **Time to Dig a 10-Foot Hole**:
#    - To find the time it would take 50 people to dig a 10-foot hole, we divide the depth of the hole by the combined rate:
#      \[
#      \text{Time} = \frac{10 \text{ feet}}{100 \text{ feet per hour}} = 0.1 \text{ hours}
#      \]
#    - Converting 0.1 hours to minutes:
#      \[
#      0.1 \text{ hours} \times 60 \text{ minutes per hour} = 6 \text{ minutes}
#      \]
#
# ### Practical Considerations
#
# While the theoretical calculation suggests it would take 50 people only 6 minutes to dig a 10-foot hole, several practical factors could affect this:
#
# 1. **Space Constraints**:
#    - A 10-foot hole may not have enough space for 50 people to work simultaneously without interfering with each other. This could lead to congestion, reduced efficiency, and potential safety hazards.
#
# 2. **Coordination and Efficiency**:
#    - The efficiency of 50 people working together may be reduced due to the need for coordination and potential overlap in their work areas. This could result in duplicated effort, confusion, and decreased productivity.
#
# 3. **Tool and Soil Factors**:
#    - The size of the shovels, the density of the soil, and other environmental factors could also impact the actual time required. For instance, if the soil is particularly hard or rocky, it may take longer to dig through it, even with 50 people working together.
#
# 4. **Logistical Challenges**:
#    - Managing a team of 50 people digging a single hole would require significant logistical planning, including organizing shifts, assigning tasks, and ensuring adequate supervision. This could add to the overall time required to complete the task.
#
# ### Conclusion
#
# In an ideal scenario where 50 people can work simultaneously and efficiently without any practical limitations, it would theoretically take them about 6 minutes to dig a 10-foot hole. However, in real-world conditions, the time required would likely be longer due to space constraints, coordination challenges, tool and soil factors, and logistical complexities. A more realistic estimate would need to take these factors into account, potentially resulting in a longer time frame.
